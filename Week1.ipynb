# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadAinurRiziq13/PCVK_Ganjil_2024/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Praktikum
#
# langkah 1

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow #for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# langkah 2

# %%
#membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://www.purina.co.id/sites/default/files/2021-12/Gourmet-mobile.jpg"]
#baca dan tampikan image
#loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)
  image = cv.resize(image,(0,0),fx=0.5,fy=0.5)
  image_2 = cv.cvtColor(image,cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image,image_2))
  cv2_imshow(final_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=930x348>

# %% [markdown]
# langakah 3

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  348  x  465
# <PIL.Image.Image image mode=RGB size=465x348>

# %% [markdown]
# langkah 4

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis horizontal dtengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2,image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=930x348>

# %% [markdown]
# ### pertanyaan
#
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan?
# Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
# ![image.png](data:image/png;base64,...)
# <br>
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
# 4. Perhatikan potongan kode progam berikut :
# ![image.png](data:image/png;base64,...)
# <br>
# Apakah kegunaan kode [255,255,255] ? Jelaskan!
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
#
# ### jawaban
# 1. karena, Google Colab adalah tool gratis berbasis cloud yang memungkinkan penulisan dan eksekusi Python di browser tanpa instalasi. Mendukung pustaka AI, akses GPU gratis, dan memudahkan kolaborasi serta berbagi kode melalui Google Drive.
# 2. .
#   - numpy untuk operasi matematika tingkat tinggi pada array dan matriks, sangat berguna untuk komputasi ilmiah.
#   - pandas untuk manipulasi dan analisis data, terutama dalam bentuk tabel (DataFrames).
#   - cv2 untuk pengolahan citra dan video, yang mendukung berbagai operasi seperti deteksi objek, filtering, dan transformasi gambar.
#   - cv2_imshow untuk menampilkan gambar dengan OpenCV, karena `cv2.imshow()` biasa tidak didukung di lingkungan Colab.
#   - io dari scikit-image, untuk membaca dan menulis gambar dari/ke berbagai format file.
#   - transform dari scikit-image, untuk melakukan transformasi geometris pada gambar, seperti rotasi, perubahan ukuran, dan warping.
#   - Image dari PIL (Python Imaging Library) untuk memanipulasi gambar, seperti membuka, mengubah format, dan mengedit gambar.
#   - Matplotlib untuk membuat visualisasi data seperti grafik, diagram, dan juga
#   dapat digunakan untuk menampilkan gambar.
#
# - tidak semua library nya digunakan, libary yang digunakan adalah cv2, cv2_imshow, dan io
#
# 3. mengecilkan gambar menjadi 50% dari ukuran aslinya, baik dalam hal lebar maupun tinggi dan jika tidak dilakukan ukuran gambar akan tetap sama
# 4. kode [255,255,255] merupakan kode rgb untuk warna putih
# 5. Pixel menentukan detail dalam sebuah gambar, dan resolusi yang lebih tinggi akan meningkatkan jumlah pixel sehingga menghasilkan gambar yang lebih tajam dan detail.

# %% [markdown]
# ### Tugas
#
# 1. Lakukan langkah-langkah praktikum seperti diatas
# 2. Buat garis vertikal dan garis menyilang diagonal pada image keluaran

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat garis vertikal di tengah image
for x in range(tinggi):
    image_3[x, int(lebar / 2)] = [255, 255, 255]

# Gabungkan gambar asli dengan gambar yang memiliki garis vertikal
vertical_combined = cv.hconcat((image_2, image_3))

# Membuat tanda silang (garis diagonal)
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
for i in range(tinggi):
    # Garis diagonal dari kiri atas ke kanan bawah
    x = int(i * (lebar / tinggi))
    image_3[i, x] = [255, 255, 255]

    # Garis diagonal dari kanan atas ke kiri bawah
    y = int(lebar - (i * (lebar / tinggi)))
    image_3[i, y - 1] = [255, 255, 255]

# Gabungkan gambar asli dengan gambar yang memiliki tanda silang
cross_combined = cv.hconcat((image_2, image_3))

# Gabungkan kedua hasil di atas secara vertikal
final_output = cv.vconcat((vertical_combined, cross_combined))

# Tampilkan output final
cv2_imshow(final_output)
# Out:
# <PIL.Image.Image image mode=RGB size=930x696>

# %% [markdown]
# 3. Buat garis horisontal berwarna putih dibagian tengah gambar dengan panjang
# tertentu

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = image_2.copy()

# Panjang garis yang diinginkan (misalnya, setengah dari lebar gambar)
panjang_garis = lebar // 2

# Posisi awal dan akhir dari garis
start_x = (lebar - panjang_garis) // 2
end_x = start_x + panjang_garis

# Membuat garis horizontal di tengah gambar dengan panjang tertentu
for y in range(start_x, end_x):
    image_3[int(tinggi / 2), y] = [255, 255, 255]

# Gabungkan gambar asli dengan gambar yang memiliki garis horizontal
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=930x348>

# %% [markdown]
#  4.  Buat kotak menggunakan kumpulan pixel warna putih di sembarang tempat dalam gambar

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = image_2.copy()

# Ukuran kotak
box_width = 200  # lebar kotak
box_height = 100  # tinggi kotak

# Lokasi acak untuk kotak (koordinat kiri atas kotak)
start_x = 140
start_y = 100

# Menggambar kotak menggunakan kumpulan pixel putih
for y in range(start_y, start_y + box_height):
    for x in range(start_x, start_x + box_width):
        image_3[y, x] = [255, 255, 255]

# Gabungkan gambar asli dengan gambar yang memiliki kotak putih
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=930x348>

# %%
# Baca gambar menggunakan OpenCV
image_bgr = cv.imread('sample_data/KTP.jpeg')

# Konversi gambar BGR ke RGB untuk ditampilkan dengan Matplotlib
image_rgb = cv.cvtColor(image_bgr, cv.COLOR_BGR2RGB)

# Menyalin gambar untuk modifikasi
image_with_boxes = image_rgb.copy()

# Ukuran kotak pertama
box1_width = 380  # lebar kotak
box1_height = 30  # tinggi kotak
start_x1 = 180
start_y1 = 70

# Menggambar kotak pertama
for y in range(start_y1, start_y1 + box1_height):
    for x in range(start_x1, start_x1 + box1_width):
        if y < image_with_boxes.shape[0] and x < image_with_boxes.shape[1]:  # Menghindari akses di luar batas gambar
            image_with_boxes[y, x] = [255, 255, 255]

# Ukuran kotak kedua
box2_width = 250  # lebar kotak
box2_height = 20  # tinggi kotak
start_x2 = 190
start_y2 = 120

# Menggambar kotak kedua
for y in range(start_y2, start_y2 + box2_height):
    for x in range(start_x2, start_x2 + box2_width):
        if y < image_with_boxes.shape[0] and x < image_with_boxes.shape[1]:  # Menghindari akses di luar batas gambar
            image_with_boxes[y, x] = [255, 255, 255]

# Menampilkan gambar asli dengan OpenCV menggunakan cv2_imshow
cv2_imshow(image_bgr)

# Menampilkan gambar dengan kotak putih menggunakan Matplotlib
plt.imshow(image_with_boxes)
plt.axis('off')  # Menyembunyikan sumbu
plt.show()
# Out:
# <PIL.Image.Image image mode=RGB size=800x488>
